# %%
import numpy as np
import matplotlib.pyplot as plt
from sunraster.instr.spice import read_spice_l2_fits
import h5py
import sunpy 
import sunpy.map
from correct_2d_psf import get_fwd_matrices, correct_spice_raster
from util import bindown, as_dict, get_iris_data, masked_median_filter, get_mask_errs
from fit_spice_lines import get_overall_center, fit_spice_lines as fsl
import astropy
from astropy.visualization import (ImageNormalize, AsinhStretch)
from astropy import constants as const
import juanfit
import importlib
importlib.reload(juanfit)
from juanfit import SpectrumFit2D

from copy import deepcopy
# Out:
# /home/yjzhu/spice_psf/util.py:37: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit(fastmath=True, parallel=True)

# %%
spice_raster = read_spice_l2_fits("../src/solo_L2_spice-n-ras_20221024T231535_V07_150995398-000.fits")
# Out:
# WARNING: FITSFixedWarning: CROTA = 4.69506977124 / [deg] S/C counter-clockwise roll rel to Solar N
# keyword looks very much like CROTAn but isn't. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJDREF to 59876.969164 from DATEREF.
# Set MJD-OBS to 59876.969164 from DATE-OBS.
# Set MJD-BEG to 59876.969164 from DATE-BEG.
# Set MJD-AVG to 59877.036108 from DATE-AVG.
# Set MJD-END to 59877.103050 from DATE-END'. [astropy.wcs.wcs]
# WARNING: UnitsWarning: 'W/m2/sr/nm' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]

# %%
spice_raster.keys()
# Out:
# dict_keys(['O III 703 / Mg IX 706 (Merged)', 'S IV 750 - Peak', 'N IV 765 - Peak', 'Ne VIII 770 - Peak', 'S V 786 / O IV 787 (Merged)', 'N III 991 (Merged)'])

# %%
spice_NeVIII_770_window = spice_raster["Ne VIII 770 - Peak"]

# %%
spice_NeVIII_770_window.wcs
# Out:
# WCS Keywords
#
# Number of WCS axes: 4
# CTYPE : 'HPLN-TAN' 'HPLT-TAN' 'WAVE' 'TIME'
# CRVAL : 0.29494045034444444 0.12210741052555556 7.70123302e-08 5783.875
# CRPIX : 96.5 416.5 25.5 1.0
# PC1_1 PC1_2 PC1_3 PC1_4  : 0.996644433832 -0.0224685795869 0.0 0.0
# PC2_1 PC2_2 PC2_3 PC2_4  : 0.298188520767 0.996644433832 0.0 0.0
# PC3_1 PC3_2 PC3_3 PC3_4  : 0.0 0.0 1.0 0.0
# PC4_1 PC4_2 PC4_3 PC4_4  : -60.25 0.0 0.0 1.0
# CDELT : 0.0011111111111111111 0.00030500000000000004 9.751700000000001e-12 1.0
# NAXIS : 192  832  50  1

# %%
spice_NeVIII_770_window.data.shape
# Out:
# (1, 50, 832, 192)

# %%
NeVIII_770_window_rebin = spice_NeVIII_770_window.rebin((1,50,1,1))[0,0,:,:]

# %%
NeVIII_770_window_int_map = sunpy.map.Map(NeVIII_770_window_rebin.data, NeVIII_770_window_rebin.meta)

# %%
NeVIII_770_window_int_map.plot_settings['cmap'] = 'viridis'
NeVIII_770_window_int_map.plot_settings['aspect'] = aspect=NeVIII_770_window_int_map.scale.axis2/NeVIII_770_window_int_map.scale.axis1
NeVIII_770_window_int_map.plot_settings['norm'] = ImageNormalize(stretch=AsinhStretch(0.1))

# %%
NeVIII_770_window_int_map.plot()

# %%
spice_dat = deepcopy(spice_NeVIII_770_window.data[0])
specmin = np.nanmin(spice_NeVIII_770_window.data[0], axis=2)
spice_dat = spice_dat - specmin[:,:,np.newaxis]
# Out:
# /tmp/ipykernel_15515/491910699.py:2: RuntimeWarning: All-NaN slice encountered
#   specmin = np.nanmin(spice_NeVIII_770_window.data[0], axis=2)

# %%
spice_dat.shape
# Out:
# (50, 832, 192)

# %%
plt.imshow(np.nansum(spice_dat, axis=0)[:,:],origin="lower",norm=ImageNormalize(stretch=AsinhStretch(0.1)),
           aspect=1/4)

# %%
spice_hdr = spice_NeVIII_770_window.meta.original_header
# This exponent sets the non-gaussianity of the PSF core, 1 = Gaussian
# It also also changes its width somewhat, which is not ideal...
yl_core_xpo = 1.0

# Rotation angle of the PSF, both core and wings
psf_yl_angle = -13*np.pi/180

# FWHMs of PSF core. First argument is width along y axis before rotation,
# and is in arcseconds. Second is along lambda axis and is in angstrom.
fwhm_core0_yl = np.array([5.5, 1.15])

# This descriptor for plots should be manually edited to reflect the PSF parameters
gaussian_desc = '2-part Gaussian PSF'

fwhm_wing0_yl = np.array([15.0, 3]) # FWHMs of PSF wings in arcseconds and angstroms, respectively
desc_str='; standard wing aspect ratio'

# Fraction of overall PSF amplitude in wings (core weight is 1.0 - wing_weight).
# PSFs have unit peak amplitude, -- PLEASE NOTE: they do not integrate to 1.
wing_weight = 0.21

# %%
spice_hdr["NBIN1"], spice_hdr["NBIN2"], spice_hdr["NBIN3"]
# Out:
# (1, 1, 1)

# %%
rebin_facs = [1,4,1]

# %%
spicedat_bindown = bindown(spice_dat[:,120:700,:],np.round(np.array(spice_dat[:,120:700,:].shape)/rebin_facs).astype(np.int32))
spicedat_bindown.shape
# Out:
# (50, 145, 192)

# %%
plt.imshow(np.nansum(spicedat_bindown, axis=0)[:,:],origin="lower",norm=ImageNormalize(stretch=AsinhStretch(0.1)),
              aspect=1)

# %%
plt.imshow((np.nansum(spicedat_bindown[:,5:30,180:195], axis=0)**(1./2.2)),origin="lower",aspect=1)
plt.colorbar()

# %%
spice_err_fac = np.nanstd(spicedat_bindown[:,5:30,180:195])

# %%
# spicedat_bindown = spicedat_bindown - np.nanmedian(spicedat_bindown[:,125:175,0:25])

# %%
spice_dat1 = deepcopy(spicedat_bindown).transpose([2,1,0]).astype(np.float32)

# %%
spice_corr_dat, spice_corr_chi2s, metadict = correct_spice_raster(spice_dat1, spice_hdr, fwhm_core0_yl, fwhm_wing0_yl, psf_yl_angle, wing_weight,
                                                                  super_fac=1, psf_thold_core=0.0005, spice_bin_facs=rebin_facs,)
# Out:
# Correcting Ne VIII 770 - Peak; ref. wavelength=767.6366184999999
# Computing PSF Core:
# 4.979997240998759 % done after 0.472942590713501 seconds
# 9.97378948820527 % done after 0.9410679340362549 seconds
# 14.96758173541178 % done after 1.4481754302978516 seconds
# 19.96137398261829 % done after 1.9269049167633057 seconds
# 24.955166229824805 % done after 2.377291440963745 seconds
# 29.948958477031315 % done after 2.8543872833251953 seconds
# 34.942750724237825 % done after 3.301982879638672 seconds
# 39.93654297144434 % done after 3.7403087615966797 seconds
# 44.930335218650846 % done after 4.188112258911133 seconds
# 49.92412746585736 % done after 4.627228736877441 seconds
# 54.917919713063874 % done after 5.063722848892212 seconds
# 59.91171196027038 % done after 5.501899480819702 seconds
# 64.9055042074769 % done after 5.940347909927368 seconds
# 69.89929645468341 % done after 6.381308078765869 seconds
# 74.89308870188992 % done after 6.822024583816528 seconds
# 79.88688094909642 % done after 7.2662742137908936 seconds
# 84.88067319630294 % done after 7.707571029663086 seconds
# 89.87446544350945 % done after 8.14800500869751 seconds
# 94.86825769071596 % done after 8.588207244873047 seconds
# 99.86204993792248 % done after 9.032700538635254 seconds
# Computing PSF Wings:
# 4.979997240998759 % done after 0.7106001377105713 seconds
# 9.97378948820527 % done after 1.419734239578247 seconds
# 14.96758173541178 % done after 2.132936477661133 seconds
# 19.96137398261829 % done after 2.8384594917297363 seconds
# 24.955166229824805 % done after 3.541933536529541 seconds
# 29.948958477031315 % done after 4.251795530319214 seconds
# 34.942750724237825 % done after 4.95963191986084 seconds
# 39.93654297144434 % done after 5.6673901081085205 seconds
# 44.930335218650846 % done after 6.4194724559783936 seconds
# 49.92412746585736 % done after 7.173024892807007 seconds
# 54.917919713063874 % done after 7.908526182174683 seconds
# 59.91171196027038 % done after 8.621125221252441 seconds
# 64.9055042074769 % done after 9.33616828918457 seconds
# 69.89929645468341 % done after 10.04906153678894 seconds
# 74.89308870188992 % done after 10.76126503944397 seconds
# 79.88688094909642 % done after 11.474671602249146 seconds
# 84.88067319630294 % done after 12.18775725364685 seconds
# 89.87446544350945 % done after 12.90250849723816 seconds
# 94.86825769071596 % done after 13.615250825881958 seconds
# 99.86204993792248 % done after 14.329728603363037 seconds
# Computing Symmetric PSF for output:
# 4.979997240998759 % done after 0.31775379180908203 seconds
# 9.97378948820527 % done after 0.6361443996429443 seconds
# 14.96758173541178 % done after 0.9690039157867432 seconds
# 19.96137398261829 % done after 1.290705919265747 seconds
# 24.955166229824805 % done after 1.6120266914367676 seconds
# 29.948958477031315 % done after 1.9389595985412598 seconds
# 34.942750724237825 % done after 2.274566173553467 seconds
# 39.93654297144434 % done after 2.595080852508545 seconds
# 44.930335218650846 % done after 2.9165453910827637 seconds
# 49.92412746585736 % done after 3.237126588821411 seconds
# 54.917919713063874 % done after 3.557525157928467 seconds
# 59.91171196027038 % done after 3.8791425228118896 seconds
# 64.9055042074769 % done after 4.2019007205963135 seconds
# 69.89929645468341 % done after 4.525210380554199 seconds
# 74.89308870188992 % done after 4.85280966758728 seconds
# 79.88688094909642 % done after 5.173712968826294 seconds
# 84.88067319630294 % done after 5.496574401855469 seconds
# 89.87446544350945 % done after 5.823238134384155 seconds
# 94.86825769071596 % done after 6.156050443649292 seconds
# 99.86204993792248 % done after 6.489275217056274 seconds
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Use of unsupported NumPy function 'numpy.unravel_index' or unsupported use of the function.
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
# During: typing of get attribute at /home/yjzhu/spice_psf/util.py (40)
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "_masked_medfilt_inner" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "../../../spice_psf/util.py", line 37:
# def masked_median_filter(data,mask,radius,footprint=None,missing=0.0,footprint_ind_offset=0):
#     <source elided>
#
# @numba.jit(fastmath=True, parallel=True)
# ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../spice_psf/util.py", line 37:
# def masked_median_filter(data,mask,radius,footprint=None,missing=0.0,footprint_ind_offset=0):
#     <source elided>
#
# @numba.jit(fastmath=True, parallel=True)
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Use of unsupported NumPy function 'numpy.unravel_index' or unsupported use of the function.
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
# During: typing of get attribute at /home/yjzhu/spice_psf/util.py (40)
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "_masked_medfilt_inner" was compiled in object mode without forceobj=True.
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# Correcting the PSF:
# 4.934298276901245 s; Finished slit index 0 of 192 11 of 40 iterations taken, chi^2= 0.03712192830862034
# 10.005622625350952 s; Finished slit index 1 of 192 10 of 40 iterations taken, chi^2= 0.01740784122512423
# 17.50937032699585 s; Finished slit index 2 of 192 12 of 40 iterations taken, chi^2= 0.02194911267894965
# 24.865212202072144 s; Finished slit index 3 of 192 12 of 40 iterations taken, chi^2= 0.019844895908354154
# 31.02686619758606 s; Finished slit index 4 of 192 11 of 40 iterations taken, chi^2= 0.017145651335301704
# 35.306252002716064 s; Finished slit index 5 of 192 10 of 40 iterations taken, chi^2= 0.015325608461488784
# 40.206360816955566 s; Finished slit index 6 of 192 10 of 40 iterations taken, chi^2= 0.016526718622739595
# 47.09708213806152 s; Finished slit index 7 of 192 12 of 40 iterations taken, chi^2= 0.018017071857330806
# 54.14425563812256 s; Finished slit index 8 of 192 12 of 40 iterations taken, chi^2= 0.019629809734798123
# 57.49549317359924 s; Finished slit index 9 of 192 9 of 40 iterations taken, chi^2= 0.01807243870336883
# 61.234630823135376 s; Finished slit index 10 of 192 10 of 40 iterations taken, chi^2= 0.019252005057010673
# 66.21854209899902 s; Finished slit index 11 of 192 11 of 40 iterations taken, chi^2= 0.01963477115922165
# 72.52746176719666 s; Finished slit index 12 of 192 12 of 40 iterations taken, chi^2= 0.020273508381830372
# 76.99920988082886 s; Finished slit index 13 of 192 11 of 40 iterations taken, chi^2= 0.01700823202027852
# 88.09703397750854 s; Finished slit index 14 of 192 14 of 40 iterations taken, chi^2= 0.016636924722131935
# 100.13515591621399 s; Finished slit index 15 of 192 15 of 40 iterations taken, chi^2= 0.015867776339283386
# 110.61084055900574 s; Finished slit index 16 of 192 14 of 40 iterations taken, chi^2= 0.016225319352958987
# 123.82305097579956 s; Finished slit index 17 of 192 15 of 40 iterations taken, chi^2= 0.016028276105672958
# 136.1865634918213 s; Finished slit index 18 of 192 15 of 40 iterations taken, chi^2= 0.015850774843220235
# 146.1819417476654 s; Finished slit index 19 of 192 14 of 40 iterations taken, chi^2= 0.01889633879820515
# 151.71404480934143 s; Finished slit index 20 of 192 11 of 40 iterations taken, chi^2= 0.020178646861347068
# 157.72167229652405 s; Finished slit index 21 of 192 12 of 40 iterations taken, chi^2= 0.017285353287168757
# 163.02741694450378 s; Finished slit index 22 of 192 11 of 40 iterations taken, chi^2= 0.01902976548270417
# 168.42626571655273 s; Finished slit index 23 of 192 11 of 40 iterations taken, chi^2= 0.016617837853588887
# 177.381418466568 s; Finished slit index 24 of 192 13 of 40 iterations taken, chi^2= 0.016210707642445726
# 188.60464668273926 s; Finished slit index 25 of 192 14 of 40 iterations taken, chi^2= 0.017147942118815304
# 200.6413848400116 s; Finished slit index 26 of 192 16 of 40 iterations taken, chi^2= 0.014941571933366352
# 215.93960213661194 s; Finished slit index 27 of 192 17 of 40 iterations taken, chi^2= 0.0161821155353891
# 228.25806593894958 s; Finished slit index 28 of 192 16 of 40 iterations taken, chi^2= 0.0184337136410834
# 237.938946723938 s; Finished slit index 29 of 192 16 of 40 iterations taken, chi^2= 0.01820509601906395
# 251.48441433906555 s; Finished slit index 30 of 192 17 of 40 iterations taken, chi^2= 0.015475714938897532
# 264.00560879707336 s; Finished slit index 31 of 192 15 of 40 iterations taken, chi^2= 0.01718294139200463
# 276.6007034778595 s; Finished slit index 32 of 192 16 of 40 iterations taken, chi^2= 0.0181665891229666
# 288.72442603111267 s; Finished slit index 33 of 192 16 of 40 iterations taken, chi^2= 0.019144830105186042
# 300.78639483451843 s; Finished slit index 34 of 192 16 of 40 iterations taken, chi^2= 0.018583523149489127
# 311.41757464408875 s; Finished slit index 35 of 192 15 of 40 iterations taken, chi^2= 0.017432758585691495
# 320.5706079006195 s; Finished slit index 36 of 192 14 of 40 iterations taken, chi^2= 0.018890144481672633
# 334.2512483596802 s; Finished slit index 37 of 192 16 of 40 iterations taken, chi^2= 0.019578972020467888
# 346.8622376918793 s; Finished slit index 38 of 192 16 of 40 iterations taken, chi^2= 0.016331071673557008
# 360.7035791873932 s; Finished slit index 39 of 192 17 of 40 iterations taken, chi^2= 0.01853761356173399
# 373.2965726852417 s; Finished slit index 40 of 192 15 of 40 iterations taken, chi^2= 0.01668999362369579
# 385.9673511981964 s; Finished slit index 41 of 192 16 of 40 iterations taken, chi^2= 0.01623898053166154
# 399.25653409957886 s; Finished slit index 42 of 192 15 of 40 iterations taken, chi^2= 0.018662290134527925
# 411.97532963752747 s; Finished slit index 43 of 192 15 of 40 iterations taken, chi^2= 0.01705772596646649
# 423.16354513168335 s; Finished slit index 44 of 192 14 of 40 iterations taken, chi^2= 0.013975263664599035
# 431.1550145149231 s; Finished slit index 45 of 192 13 of 40 iterations taken, chi^2= 0.014535022635852822
# 437.04211831092834 s; Finished slit index 46 of 192 11 of 40 iterations taken, chi^2= 0.016005053910869472
# 442.3395347595215 s; Finished slit index 47 of 192 11 of 40 iterations taken, chi^2= 0.01593025644845619
# 449.16275238990784 s; Finished slit index 48 of 192 12 of 40 iterations taken, chi^2= 0.01689006361525366
# 453.5952866077423 s; Finished slit index 49 of 192 10 of 40 iterations taken, chi^2= 0.015263935897564465
# 459.2851297855377 s; Finished slit index 50 of 192 11 of 40 iterations taken, chi^2= 0.015636328595036164
# 463.43306517601013 s; Finished slit index 51 of 192 10 of 40 iterations taken, chi^2= 0.016064735765326386
# 466.1868040561676 s; Finished slit index 52 of 192 9 of 40 iterations taken, chi^2= 0.01806912673125639
# 469.13078689575195 s; Finished slit index 53 of 192 9 of 40 iterations taken, chi^2= 0.015973153294649392
# 472.6349632740021 s; Finished slit index 54 of 192 9 of 40 iterations taken, chi^2= 0.019376905942067774
# 476.74306988716125 s; Finished slit index 55 of 192 10 of 40 iterations taken, chi^2= 0.016210068129836015
# 479.8935399055481 s; Finished slit index 56 of 192 9 of 40 iterations taken, chi^2= 0.016251236466075594
# 483.6430697441101 s; Finished slit index 57 of 192 10 of 40 iterations taken, chi^2= 0.016619416033145398
# 487.67286920547485 s; Finished slit index 58 of 192 10 of 40 iterations taken, chi^2= 0.015793929188116115
# 491.61604261398315 s; Finished slit index 59 of 192 10 of 40 iterations taken, chi^2= 0.01475687228538451
# 495.81237983703613 s; Finished slit index 60 of 192 10 of 40 iterations taken, chi^2= 0.014639354835565745
# 500.87362241744995 s; Finished slit index 61 of 192 11 of 40 iterations taken, chi^2= 0.019664372664698556
# 505.26188707351685 s; Finished slit index 62 of 192 10 of 40 iterations taken, chi^2= 0.01596025283805589
# 511.32327246665955 s; Finished slit index 63 of 192 11 of 40 iterations taken, chi^2= 0.016352425085369052
# 518.9229829311371 s; Finished slit index 64 of 192 12 of 40 iterations taken, chi^2= 0.016916908848541773
# 525.2038052082062 s; Finished slit index 65 of 192 11 of 40 iterations taken, chi^2= 0.01570873622212321
# 533.1255807876587 s; Finished slit index 66 of 192 12 of 40 iterations taken, chi^2= 0.016331090334839045
# 539.7971956729889 s; Finished slit index 67 of 192 12 of 40 iterations taken, chi^2= 0.018019138894517908
# 544.5675749778748 s; Finished slit index 68 of 192 10 of 40 iterations taken, chi^2= 0.016547696402890923
# 552.4354293346405 s; Finished slit index 69 of 192 12 of 40 iterations taken, chi^2= 0.018407872320381935
# 558.8510613441467 s; Finished slit index 70 of 192 11 of 40 iterations taken, chi^2= 0.015210141023673206
# 563.2624273300171 s; Finished slit index 71 of 192 10 of 40 iterations taken, chi^2= 0.01747345690802022
# 566.0601122379303 s; Finished slit index 72 of 192 9 of 40 iterations taken, chi^2= 0.019774730915497522
# 568.8277039527893 s; Finished slit index 73 of 192 9 of 40 iterations taken, chi^2= 0.019176163205750822
# 571.8416616916656 s; Finished slit index 74 of 192 9 of 40 iterations taken, chi^2= 0.018901666853706534
# 574.9285476207733 s; Finished slit index 75 of 192 9 of 40 iterations taken, chi^2= 0.01899221176697964
# 577.9335751533508 s; Finished slit index 76 of 192 9 of 40 iterations taken, chi^2= 0.01905521370570138
# 582.2563726902008 s; Finished slit index 77 of 192 10 of 40 iterations taken, chi^2= 0.018493915181543228
# 585.3707478046417 s; Finished slit index 78 of 192 8 of 40 iterations taken, chi^2= 0.017003583775865205
# 588.2860395908356 s; Finished slit index 79 of 192 9 of 40 iterations taken, chi^2= 0.02099597620159356
# 590.8791425228119 s; Finished slit index 80 of 192 8 of 40 iterations taken, chi^2= 0.019789312183785695
# 593.5171535015106 s; Finished slit index 81 of 192 9 of 40 iterations taken, chi^2= 0.01961036579510124
# 596.1421613693237 s; Finished slit index 82 of 192 9 of 40 iterations taken, chi^2= 0.020473532437939493
# 599.1771285533905 s; Finished slit index 83 of 192 9 of 40 iterations taken, chi^2= 0.020603019676342933
# 602.4619355201721 s; Finished slit index 84 of 192 10 of 40 iterations taken, chi^2= 0.02118182325479378
# 605.5171060562134 s; Finished slit index 85 of 192 9 of 40 iterations taken, chi^2= 0.020004086354524088
# 608.8010337352753 s; Finished slit index 86 of 192 10 of 40 iterations taken, chi^2= 0.02405822300818221
# 611.6798253059387 s; Finished slit index 87 of 192 10 of 40 iterations taken, chi^2= 0.01998057100742575
# 613.6933205127716 s; Finished slit index 88 of 192 8 of 40 iterations taken, chi^2= 0.02130148859960804
# 616.2154059410095 s; Finished slit index 89 of 192 9 of 40 iterations taken, chi^2= 0.025670423217420055
# 618.888530254364 s; Finished slit index 90 of 192 9 of 40 iterations taken, chi^2= 0.02181981472398086
# 621.651697397232 s; Finished slit index 91 of 192 9 of 40 iterations taken, chi^2= 0.018906471621332188
# 624.6819591522217 s; Finished slit index 92 of 192 8 of 40 iterations taken, chi^2= 0.01744204008009837
# 629.0121200084686 s; Finished slit index 93 of 192 10 of 40 iterations taken, chi^2= 0.017530357190246038
# 633.7614579200745 s; Finished slit index 94 of 192 10 of 40 iterations taken, chi^2= 0.01760920669956086
# 639.9532904624939 s; Finished slit index 95 of 192 15 of 40 iterations taken, chi^2= 0.025154900918970557
# 648.2761170864105 s; Finished slit index 96 of 192 12 of 40 iterations taken, chi^2= 0.018966985199596668
# 660.0839443206787 s; Finished slit index 97 of 192 15 of 40 iterations taken, chi^2= 0.019120605800792827
# 670.4799818992615 s; Finished slit index 98 of 192 13 of 40 iterations taken, chi^2= 0.01668158814914047
# 684.2477025985718 s; Finished slit index 99 of 192 16 of 40 iterations taken, chi^2= 0.018968486058829993
# 698.004207611084 s; Finished slit index 100 of 192 16 of 40 iterations taken, chi^2= 0.0175266125627931
# 711.9966304302216 s; Finished slit index 101 of 192 16 of 40 iterations taken, chi^2= 0.01779573060208389
# 722.6687717437744 s; Finished slit index 102 of 192 13 of 40 iterations taken, chi^2= 0.017774251605123158
# 732.3160214424133 s; Finished slit index 103 of 192 13 of 40 iterations taken, chi^2= 0.01809498221886106
# 741.1220190525055 s; Finished slit index 104 of 192 13 of 40 iterations taken, chi^2= 0.019268489933153228
# 745.7810690402985 s; Finished slit index 105 of 192 11 of 40 iterations taken, chi^2= 0.017157562730725794
# 752.4828774929047 s; Finished slit index 106 of 192 12 of 40 iterations taken, chi^2= 0.01874265246211741
# 756.3578352928162 s; Finished slit index 107 of 192 9 of 40 iterations taken, chi^2= 0.017498025099286052
# 762.2635776996613 s; Finished slit index 108 of 192 11 of 40 iterations taken, chi^2= 0.023164353893803297
# 768.3795540332794 s; Finished slit index 109 of 192 12 of 40 iterations taken, chi^2= 0.019767278850017958
# 774.6281545162201 s; Finished slit index 110 of 192 12 of 40 iterations taken, chi^2= 0.019597834717254573
# 778.2786386013031 s; Finished slit index 111 of 192 9 of 40 iterations taken, chi^2= 0.01681450660136372
# 781.6948201656342 s; Finished slit index 112 of 192 9 of 40 iterations taken, chi^2= 0.01698674460899336
# 784.9116983413696 s; Finished slit index 113 of 192 9 of 40 iterations taken, chi^2= 0.01778893649697699
# 787.7656061649323 s; Finished slit index 114 of 192 9 of 40 iterations taken, chi^2= 0.01923233960789986
# 790.0649192333221 s; Finished slit index 115 of 192 9 of 40 iterations taken, chi^2= 0.024308410747836903
# 791.758740901947 s; Finished slit index 116 of 192 8 of 40 iterations taken, chi^2= 0.025865262604949663
# 793.3371267318726 s; Finished slit index 117 of 192 8 of 40 iterations taken, chi^2= 0.02443778948789417
# 794.9609432220459 s; Finished slit index 118 of 192 8 of 40 iterations taken, chi^2= 0.02584352171378371
# 796.577709197998 s; Finished slit index 119 of 192 8 of 40 iterations taken, chi^2= 0.024698077474304348
# 798.6323220729828 s; Finished slit index 120 of 192 9 of 40 iterations taken, chi^2= 0.02473652325723265
# 800.9801704883575 s; Finished slit index 121 of 192 10 of 40 iterations taken, chi^2= 0.0231760226160893
# 803.631808757782 s; Finished slit index 122 of 192 9 of 40 iterations taken, chi^2= 0.024235065876329884
# 806.196168422699 s; Finished slit index 123 of 192 9 of 40 iterations taken, chi^2= 0.02425555262832769
# 809.4912114143372 s; Finished slit index 124 of 192 10 of 40 iterations taken, chi^2= 0.020062210599339343
# 812.5394501686096 s; Finished slit index 125 of 192 9 of 40 iterations taken, chi^2= 0.018464747897446926
# 814.5579741001129 s; Finished slit index 126 of 192 9 of 40 iterations taken, chi^2= 0.025320836559441933
# 816.7865397930145 s; Finished slit index 127 of 192 9 of 40 iterations taken, chi^2= 0.022279092839796594
# 819.3090062141418 s; Finished slit index 128 of 192 9 of 40 iterations taken, chi^2= 0.021900306745679013
# 822.0751996040344 s; Finished slit index 129 of 192 9 of 40 iterations taken, chi^2= 0.021846179955595867
# 825.1857852935791 s; Finished slit index 130 of 192 9 of 40 iterations taken, chi^2= 0.019550014564082282
# 828.1750302314758 s; Finished slit index 131 of 192 9 of 40 iterations taken, chi^2= 0.01785568932465833
# 830.7196137905121 s; Finished slit index 132 of 192 8 of 40 iterations taken, chi^2= 0.0206351962602781
# 834.3865699768066 s; Finished slit index 133 of 192 10 of 40 iterations taken, chi^2= 0.01948589031959752
# 838.770322561264 s; Finished slit index 134 of 192 11 of 40 iterations taken, chi^2= 0.01882550714078369
# 842.5539863109589 s; Finished slit index 135 of 192 10 of 40 iterations taken, chi^2= 0.01751422729068797
# 845.9537291526794 s; Finished slit index 136 of 192 9 of 40 iterations taken, chi^2= 0.017351868449462696
# 849.7439465522766 s; Finished slit index 137 of 192 10 of 40 iterations taken, chi^2= 0.01835807580722499
# 853.3033089637756 s; Finished slit index 138 of 192 9 of 40 iterations taken, chi^2= 0.01892956537825682
# 856.7717649936676 s; Finished slit index 139 of 192 9 of 40 iterations taken, chi^2= 0.017664770213381323
# 860.2647206783295 s; Finished slit index 140 of 192 10 of 40 iterations taken, chi^2= 0.020213961976057796
# 863.5710535049438 s; Finished slit index 141 of 192 9 of 40 iterations taken, chi^2= 0.01619389886645631
# 867.6313223838806 s; Finished slit index 142 of 192 9 of 40 iterations taken, chi^2= 0.01783819837789585
# 871.565634727478 s; Finished slit index 143 of 192 10 of 40 iterations taken, chi^2= 0.01780991957576723
# 875.5106644630432 s; Finished slit index 144 of 192 9 of 40 iterations taken, chi^2= 0.01633278570902622
# 880.3070688247681 s; Finished slit index 145 of 192 10 of 40 iterations taken, chi^2= 0.016347169547505796
# 884.5902388095856 s; Finished slit index 146 of 192 9 of 40 iterations taken, chi^2= 0.015645945311166587
# 889.2107408046722 s; Finished slit index 147 of 192 10 of 40 iterations taken, chi^2= 0.017328640522864997
# 893.4449875354767 s; Finished slit index 148 of 192 10 of 40 iterations taken, chi^2= 0.017360952073215582
# 896.8682441711426 s; Finished slit index 149 of 192 9 of 40 iterations taken, chi^2= 0.019238396231014903
# 899.684520483017 s; Finished slit index 150 of 192 9 of 40 iterations taken, chi^2= 0.01886054745138999
# 901.1942923069 s; Finished slit index 151 of 192 8 of 40 iterations taken, chi^2= 0.025503996813107582
# 902.861519575119 s; Finished slit index 152 of 192 8 of 40 iterations taken, chi^2= 0.02054027997426824
# 905.7008373737335 s; Finished slit index 153 of 192 10 of 40 iterations taken, chi^2= 0.018828828125434724
# 909.7889933586121 s; Finished slit index 154 of 192 10 of 40 iterations taken, chi^2= 0.016512435652980887
# 912.5903899669647 s; Finished slit index 155 of 192 9 of 40 iterations taken, chi^2= 0.018317400833946125
# 915.8069443702698 s; Finished slit index 156 of 192 9 of 40 iterations taken, chi^2= 0.01863085956303312
# 920.0777380466461 s; Finished slit index 157 of 192 11 of 40 iterations taken, chi^2= 0.016997930334300897
# 924.3217191696167 s; Finished slit index 158 of 192 11 of 40 iterations taken, chi^2= 0.022292816999992207
# 927.2877902984619 s; Finished slit index 159 of 192 9 of 40 iterations taken, chi^2= 0.01835700512026918
# 931.3092565536499 s; Finished slit index 160 of 192 10 of 40 iterations taken, chi^2= 0.017634813970791634
# 936.7656373977661 s; Finished slit index 161 of 192 11 of 40 iterations taken, chi^2= 0.01932365347309086
# 943.2773215770721 s; Finished slit index 162 of 192 11 of 40 iterations taken, chi^2= 0.016728419506238094
# 947.7051656246185 s; Finished slit index 163 of 192 10 of 40 iterations taken, chi^2= 0.017043989413538678
# 953.9617309570312 s; Finished slit index 164 of 192 12 of 40 iterations taken, chi^2= 0.017810516999615493
# 958.5117423534393 s; Finished slit index 165 of 192 10 of 40 iterations taken, chi^2= 0.016943925108863687
# 962.5950605869293 s; Finished slit index 166 of 192 10 of 40 iterations taken, chi^2= 0.016093751066265056
# 968.1654896736145 s; Finished slit index 167 of 192 11 of 40 iterations taken, chi^2= 0.019392096122269973
# 973.7969331741333 s; Finished slit index 168 of 192 11 of 40 iterations taken, chi^2= 0.017178227515063163
# 979.679780960083 s; Finished slit index 169 of 192 11 of 40 iterations taken, chi^2= 0.013891413112711392
# 987.6341910362244 s; Finished slit index 170 of 192 13 of 40 iterations taken, chi^2= 0.015888090915128116
# 997.3805646896362 s; Finished slit index 171 of 192 14 of 40 iterations taken, chi^2= 0.01588083151608787
# 1010.1492502689362 s; Finished slit index 172 of 192 15 of 40 iterations taken, chi^2= 0.015070067423176408
# 1022.5154347419739 s; Finished slit index 173 of 192 14 of 40 iterations taken, chi^2= 0.015666019907614234
# 1033.582445383072 s; Finished slit index 174 of 192 14 of 40 iterations taken, chi^2= 0.017175836019654844
# 1043.594358921051 s; Finished slit index 175 of 192 14 of 40 iterations taken, chi^2= 0.015605772778759262
# 1053.245985507965 s; Finished slit index 176 of 192 14 of 40 iterations taken, chi^2= 0.01627575324409804
# 1064.9767999649048 s; Finished slit index 177 of 192 14 of 40 iterations taken, chi^2= 0.017611897166458015
# 1078.4179937839508 s; Finished slit index 178 of 192 15 of 40 iterations taken, chi^2= 0.01904506847702207
# 1092.7676012516022 s; Finished slit index 179 of 192 18 of 40 iterations taken, chi^2= 0.01618249807462123
# 1105.7954726219177 s; Finished slit index 180 of 192 15 of 40 iterations taken, chi^2= 0.01536605786236534
# 1119.4678826332092 s; Finished slit index 181 of 192 16 of 40 iterations taken, chi^2= 0.018778130625210467
# 1129.6574313640594 s; Finished slit index 182 of 192 16 of 40 iterations taken, chi^2= 0.016425529762525596
# 1146.3916573524475 s; Finished slit index 183 of 192 18 of 40 iterations taken, chi^2= 0.020720998314108514
# 1156.5054304599762 s; Finished slit index 184 of 192 14 of 40 iterations taken, chi^2= 0.016666506845682445
# 1169.6459143161774 s; Finished slit index 185 of 192 17 of 40 iterations taken, chi^2= 0.015452017496481287
# 1182.1117806434631 s; Finished slit index 186 of 192 17 of 40 iterations taken, chi^2= 0.01966524961465197
# 1192.174474477768 s; Finished slit index 187 of 192 15 of 40 iterations taken, chi^2= 0.01927128864466058
# 1200.8237204551697 s; Finished slit index 188 of 192 13 of 40 iterations taken, chi^2= 0.01612198581036108
# 1207.7823424339294 s; Finished slit index 189 of 192 12 of 40 iterations taken, chi^2= 0.018119709974350466
# 1211.3839254379272 s; Finished slit index 190 of 192 10 of 40 iterations taken, chi^2= 0.01805985569038115
# 1213.8157484531403 s; Finished slit index 191 of 192 9 of 40 iterations taken, chi^2= 0.01623959944244778

# %%
spice_sdev_guess = 0.1
corr_sdev_guess = 0.05


spice_mask, spice_err = get_mask_errs(spice_dat1.astype(np.float64), spice_err_fac)
spice_corr_mask, spice_corr_err = get_mask_errs(spice_corr_dat, spice_err_fac)

[det_origin0, det_dims0, det_scale0] = metadict["det_origin0"], metadict["det_dims0"], metadict["det_scale0"]
spice_la = spice_NeVIII_770_window.spectral_axis.to_value("Angstrom")
spice_wlcen0 = spice_la[np.nanargmax(np.nanmean(spice_dat1[:,:,:], axis=(0,1)))]
# Out:
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Use of unsupported NumPy function 'numpy.unravel_index' or unsupported use of the function.
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
# During: typing of get attribute at /home/yjzhu/spice_psf/util.py (40)
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "_masked_medfilt_inner" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "../../../spice_psf/util.py", line 37:
# def masked_median_filter(data,mask,radius,footprint=None,missing=0.0,footprint_ind_offset=0):
#     <source elided>
#
# @numba.jit(fastmath=True, parallel=True)
# ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../spice_psf/util.py", line 37:
# def masked_median_filter(data,mask,radius,footprint=None,missing=0.0,footprint_ind_offset=0):
#     <source elided>
#
# @numba.jit(fastmath=True, parallel=True)
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Use of unsupported NumPy function 'numpy.unravel_index' or unsupported use of the function.
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
# During: typing of get attribute at /home/yjzhu/spice_psf/util.py (40)
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "_masked_medfilt_inner" was compiled in object mode without forceobj=True.
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Use of unsupported NumPy function 'numpy.unravel_index' or unsupported use of the function.
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
# During: typing of get attribute at /home/yjzhu/spice_psf/util.py (40)
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "_masked_medfilt_inner" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "../../../spice_psf/util.py", line 37:
# def masked_median_filter(data,mask,radius,footprint=None,missing=0.0,footprint_ind_offset=0):
#     <source elided>
#
# @numba.jit(fastmath=True, parallel=True)
# ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../spice_psf/util.py", line 37:
# def masked_median_filter(data,mask,radius,footprint=None,missing=0.0,footprint_ind_offset=0):
#     <source elided>
#
# @numba.jit(fastmath=True, parallel=True)
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Use of unsupported NumPy function 'numpy.unravel_index' or unsupported use of the function.
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
# During: typing of get attribute at /home/yjzhu/spice_psf/util.py (40)
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "_masked_medfilt_inner" was compiled in object mode without forceobj=True.
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# /tmp/ipykernel_15515/844281563.py:10: RuntimeWarning: Mean of empty slice
#   spice_wlcen0 = spice_la[np.nanargmax(np.nanmean(spice_dat1[:,:,:], axis=(0,1)))]

# %%
spice_fits = fsl(spice_dat1, spice_err, spice_la, spice_mask, spice_wlcen0, spice_sdev_guess)

spice_corr_fits = fsl(spice_corr_dat, spice_corr_err, spice_la, spice_corr_mask, spice_wlcen0, corr_sdev_guess)
# Out:
# 0 of 192 0.0
# 10 of 192 0.0
# 20 of 192 0.0
# 30 of 192 0.0
# 40 of 192 0.0
# 50 of 192 0.0
# 60 of 192 0.0
# 70 of 192 0.0
# 80 of 192 0.0
# 90 of 192 0.0
# 100 of 192 0.0
# 110 of 192 0.0
# 120 of 192 0.0
# 130 of 192 0.0
# 140 of 192 0.0
# 150 of 192 0.0
# 160 of 192 0.0
# 170 of 192 0.0
# 180 of 192 0.0
# 190 of 192 0.0
# 191 of 192 0.0
# 0 of 192 0.0
# 10 of 192 0.0
# 20 of 192 0.0
# 30 of 192 0.0
# 40 of 192 0.0
# 50 of 192 0.0
# 60 of 192 0.0
# 70 of 192 0.0
# 80 of 192 0.0
# 90 of 192 0.0
# 100 of 192 0.0
# 110 of 192 0.0
# 120 of 192 0.0
# 130 of 192 0.0
# 140 of 192 0.0
# 150 of 192 0.0
# 160 of 192 0.0
# 170 of 192 0.0
# 180 of 192 0.0
# 190 of 192 0.0
# 191 of 192 0.0

# %%
spice_origin_vel = (spice_fits["centers"].T/spice_wlcen0 - 1)*const.c.to_value("km/s")
spice_origin_vel = spice_origin_vel - np.nanmedian(spice_origin_vel[:,:])

spice_corr_vel = (spice_corr_fits["centers"].T/spice_wlcen0 - 1)*const.c.to_value("km/s")
spice_corr_vel = spice_corr_vel - np.nanmedian(spice_corr_vel[:,:])

# %%
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(10,10),layout="constrained")

int_norm = ImageNormalize(stretch=AsinhStretch(0.1))

ax1.imshow(spice_fits["amplitudes"].T,origin="lower",norm=int_norm,aspect=1,
           cmap="sdoaia171")
plt.colorbar(ax1.images[0],ax=ax1)
ax1.set_title("Original")

ax2.imshow(spice_corr_fits["amplitudes"].T,origin="lower",norm=int_norm,aspect=1,
              cmap="sdoaia171")
plt.colorbar(ax2.images[0],ax=ax2)
ax2.set_title("Corrected")
# Out:
# Text(0.5, 1.0, 'Corrected')

# %%
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(10,10),layout="constrained")

ax1.imshow(spice_origin_vel,origin="lower",vmin=-40,vmax=40,aspect=1,
           cmap="RdBu_r")
plt.colorbar(ax1.images[0],ax=ax1)
ax1.set_title("Original")

ax2.imshow(spice_corr_vel,origin="lower",vmin=-40,vmax=40,aspect=1,
                cmap="RdBu_r")
plt.colorbar(ax2.images[0],ax=ax2)
ax2.set_title("Corrected")

for ax_ in (ax1,ax2):
    ax_.scatter(62,90,color="yellow",marker="x")

# %%
NeVIII_770_window_wvl = spice_NeVIII_770_window.spectral_axis.to_value("Angstrom")
NeVIII_deconv_rebin_fitmodel = SpectrumFit2D(spice_corr_dat[:,:,16:30].transpose([1,0,2]).astype(np.float32), NeVIII_770_window_wvl[16:30],
                                line_number=1,line_wvl_init=[770],int_max_init=0.2,fwhm_init=1,
                                same_width=False)
NeVIII_deconv_rebin_fitmodel.run_lse_mp(prev_init=False)
# Out:
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:277: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(self.multi_gaussian_diff_width, self.wvl_tofit, self.data_tofit,
# /home/yjzhu/SOLAR/MyPy/juanfit.py:277: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(self.multi_gaussian_diff_width, self.wvl_tofit, self.data_tofit,

# %%
NeVIII_deconv_rebin_fitmodel.plot_fit2d(param="vel",vmin=-50,vmax=50,vel_corr="column",ref_wvl=770.03,   
                                    aspect=1,cmap="RdBu")
# Out:
# Doppler velocity corrected by the median of each raster.

# %%
spice_corr_dat.shape
# Out:
# (192, 145, 50)

# %%
plt.plot(NeVIII_770_window_wvl, spice_corr_dat[145,50,:])
plt.plot(NeVIII_770_window_wvl, spice_dat1[145,50,:])

# %%
plt.plot(NeVIII_770_window_wvl, spice_corr_dat[60,62,:])
plt.plot(NeVIII_770_window_wvl, spice_dat1[60,62,:])
plt.axvline(NeVIII_770_window_wvl[15])
plt.axvline(NeVIII_770_window_wvl[30])

# %%
plt.plot(NeVIII_770_window_wvl, spice_corr_dat[10,20,:])
plt.plot(NeVIII_770_window_wvl, spice_dat1[10,20,:])

# %%
plt.imshow(spice_corr_dat[175,:,:],origin="lower",aspect=1/4,
           norm=ImageNormalize(stretch=AsinhStretch(0.01)))

# %%
plt.imshow(spice_dat1[175,:,:],origin="lower",aspect=1/4,
           norm=ImageNormalize(stretch=AsinhStretch(0.01)))
plt.axvline(15)
plt.axvline(34)

# %%
spice_corr_dat.shape
# Out:
# (192, 145, 50)
