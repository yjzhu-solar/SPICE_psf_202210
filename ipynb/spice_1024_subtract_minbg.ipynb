# %%
import numpy as np
import matplotlib.pyplot as plt
from sunraster.instr.spice import read_spice_l2_fits
import h5py
import sunpy 
import sunpy.map
from correct_2d_psf import get_fwd_matrices, correct_spice_raster
from util import bindown, as_dict, get_iris_data, masked_median_filter, get_mask_errs
from fit_spice_lines import get_overall_center, fit_spice_lines as fsl
import astropy
from astropy.visualization import (ImageNormalize, AsinhStretch)
from astropy import constants as const
import juanfit
import importlib
importlib.reload(juanfit)
from juanfit import SpectrumFit2D

from copy import deepcopy
# Out:
# /home/yjzhu/spice_psf/util.py:37: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit(fastmath=True, parallel=True)

# %%
spice_raster = read_spice_l2_fits("../src/solo_L2_spice-n-ras_20221024T231535_V07_150995398-000.fits")
# Out:
# WARNING: FITSFixedWarning: CROTA = 4.69506977124 / [deg] S/C counter-clockwise roll rel to Solar N
# keyword looks very much like CROTAn but isn't. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJDREF to 59876.969164 from DATEREF.
# Set MJD-OBS to 59876.969164 from DATE-OBS.
# Set MJD-BEG to 59876.969164 from DATE-BEG.
# Set MJD-AVG to 59877.036108 from DATE-AVG.
# Set MJD-END to 59877.103050 from DATE-END'. [astropy.wcs.wcs]
# WARNING: UnitsWarning: 'W/m2/sr/nm' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]

# %%
spice_raster.keys()
# Out:
# dict_keys(['O III 703 / Mg IX 706 (Merged)', 'S IV 750 - Peak', 'N IV 765 - Peak', 'Ne VIII 770 - Peak', 'S V 786 / O IV 787 (Merged)', 'N III 991 (Merged)'])

# %%
spice_NeVIII_770_window = spice_raster["Ne VIII 770 - Peak"]

# %%
spice_NeVIII_770_window.wcs
# Out:
# WCS Keywords
#
# Number of WCS axes: 4
# CTYPE : 'HPLN-TAN' 'HPLT-TAN' 'WAVE' 'TIME'
# CRVAL : 0.29494045034444444 0.12210741052555556 7.70123302e-08 5783.875
# CRPIX : 96.5 416.5 25.5 1.0
# PC1_1 PC1_2 PC1_3 PC1_4  : 0.996644433832 -0.0224685795869 0.0 0.0
# PC2_1 PC2_2 PC2_3 PC2_4  : 0.298188520767 0.996644433832 0.0 0.0
# PC3_1 PC3_2 PC3_3 PC3_4  : 0.0 0.0 1.0 0.0
# PC4_1 PC4_2 PC4_3 PC4_4  : -60.25 0.0 0.0 1.0
# CDELT : 0.0011111111111111111 0.00030500000000000004 9.751700000000001e-12 1.0
# NAXIS : 192  832  50  1

# %%
spice_NeVIII_770_window.data.shape
# Out:
# (1, 50, 832, 192)

# %%
NeVIII_770_window_rebin = spice_NeVIII_770_window.rebin((1,50,1,1))[0,0,:,:]

# %%
NeVIII_770_window_int_map = sunpy.map.Map(NeVIII_770_window_rebin.data, NeVIII_770_window_rebin.meta)

# %%
NeVIII_770_window_int_map.plot_settings['cmap'] = 'viridis'
NeVIII_770_window_int_map.plot_settings['aspect'] = aspect=NeVIII_770_window_int_map.scale.axis2/NeVIII_770_window_int_map.scale.axis1
NeVIII_770_window_int_map.plot_settings['norm'] = ImageNormalize(stretch=AsinhStretch(0.1))

# %%
NeVIII_770_window_int_map.plot()

# %%
spice_dat = deepcopy(spice_NeVIII_770_window.data[0])
specmin = np.nanmin(spice_NeVIII_770_window.data[0], axis=2)
spice_dat = spice_dat - specmin[:,:,np.newaxis]
spice_dat = spice_dat - np.nanmin(spice_dat[np.r_[12:18,33:40],:,:], axis=0)[np.newaxis,:,:]
# Out:
# /tmp/ipykernel_16712/1104687291.py:2: RuntimeWarning: All-NaN slice encountered
#   specmin = np.nanmin(spice_NeVIII_770_window.data[0], axis=2)
# /tmp/ipykernel_16712/1104687291.py:4: RuntimeWarning: All-NaN slice encountered
#   spice_dat = spice_dat - np.nanmin(spice_dat[np.r_[12:18,33:40],:,:], axis=0)[np.newaxis,:,:]

# %%
spice_dat.shape
# Out:
# (50, 832, 192)

# %%
plt.imshow(np.nansum(spice_dat, axis=0)[:,:],origin="lower",norm=ImageNormalize(stretch=AsinhStretch(0.1)),
           aspect=1/4)

# %%
spice_hdr = spice_NeVIII_770_window.meta.original_header
# This exponent sets the non-gaussianity of the PSF core, 1 = Gaussian
# It also also changes its width somewhat, which is not ideal...
yl_core_xpo = 2.0

# Rotation angle of the PSF, both core and wings
psf_yl_angle = -15*np.pi/180

# FWHMs of PSF core. First argument is width along y axis before rotation,
# and is in arcseconds. Second is along lambda axis and is in angstrom.
fwhm_core0_yl = np.array([2, 1.05])

# This descriptor for plots should be manually edited to reflect the PSF parameters
gaussian_desc = '2-part Gaussian PSF'

fwhm_wing0_yl = np.array([10.0, 2.0]) # FWHMs of PSF wings in arcseconds and angstroms, respectively
desc_str='; standard wing aspect ratio'

# Fraction of overall PSF amplitude in wings (core weight is 1.0 - wing_weight).
# PSFs have unit peak amplitude, -- PLEASE NOTE: they do not integrate to 1.
wing_weight = 0.2

# %%
spice_hdr["NBIN1"], spice_hdr["NBIN2"], spice_hdr["NBIN3"]
# Out:
# (1, 1, 1)

# %%
rebin_facs = [1,4,1]

# %%
spicedat_bindown = bindown(spice_dat[:,120:700,:],np.round(np.array(spice_dat[:,120:700,:].shape)/rebin_facs).astype(np.int32))
spicedat_bindown.shape
# Out:
# (50, 145, 192)

# %%
plt.imshow(np.nansum(spicedat_bindown, axis=0)[:,:],origin="lower",norm=ImageNormalize(stretch=AsinhStretch(0.1)),
              aspect=1)

# %%
plt.imshow((np.nansum(spicedat_bindown[:,5:30,180:195], axis=0)**(1./2.2)),origin="lower",aspect=1)
plt.colorbar()

# %%
spice_err_fac = np.nanstd(spicedat_bindown[:,5:30,180:195])

# %%
# spicedat_bindown = spicedat_bindown - np.nanmedian(spicedat_bindown[:,125:175,0:25])

# %%
spice_dat1 = deepcopy(spicedat_bindown).transpose([2,1,0]).astype(np.float32)

# %%
spice_corr_dat, spice_corr_chi2s, metadict = correct_spice_raster(spice_dat1, spice_hdr, fwhm_core0_yl, fwhm_wing0_yl, psf_yl_angle, wing_weight,
                                                                  super_fac=1, psf_thold_core=0.0005, spice_bin_facs=rebin_facs,)
# Out:
# Correcting Ne VIII 770 - Peak; ref. wavelength=767.6366184999999
# Computing PSF Core:
# 4.979997240998759 % done after 0.3495824337005615 seconds
# 9.97378948820527 % done after 0.7021939754486084 seconds
# 14.96758173541178 % done after 1.0587835311889648 seconds
# 19.96137398261829 % done after 1.4122498035430908 seconds
# 24.955166229824805 % done after 1.7631282806396484 seconds
# 29.948958477031315 % done after 2.1162543296813965 seconds
# 34.942750724237825 % done after 2.4682462215423584 seconds
# 39.93654297144434 % done after 2.8206567764282227 seconds
# 44.930335218650846 % done after 3.1728878021240234 seconds
# 49.92412746585736 % done after 3.526106834411621 seconds
# 54.917919713063874 % done after 3.8797900676727295 seconds
# 59.91171196027038 % done after 4.23585057258606 seconds
# 64.9055042074769 % done after 4.590218544006348 seconds
# 69.89929645468341 % done after 4.95285439491272 seconds
# 74.89308870188992 % done after 5.326281785964966 seconds
# 79.88688094909642 % done after 5.699028491973877 seconds
# 84.88067319630294 % done after 6.073639154434204 seconds
# 89.87446544350945 % done after 6.429553031921387 seconds
# 94.86825769071596 % done after 6.782166481018066 seconds
# 99.86204993792248 % done after 7.136138439178467 seconds
# Computing PSF Wings:
# 4.979997240998759 % done after 0.500429630279541 seconds
# 9.97378948820527 % done after 1.0046567916870117 seconds
# 14.96758173541178 % done after 1.508516550064087 seconds
# 19.96137398261829 % done after 2.0116117000579834 seconds
# 24.955166229824805 % done after 2.512627124786377 seconds
# 29.948958477031315 % done after 3.012906789779663 seconds
# 34.942750724237825 % done after 3.5136728286743164 seconds
# 39.93654297144434 % done after 4.018361568450928 seconds
# 44.930335218650846 % done after 4.51771092414856 seconds
# 49.92412746585736 % done after 5.015779495239258 seconds
# 54.917919713063874 % done after 5.5136988162994385 seconds
# 59.91171196027038 % done after 6.0125038623809814 seconds
# 64.9055042074769 % done after 6.511677265167236 seconds
# 69.89929645468341 % done after 7.014677047729492 seconds
# 74.89308870188992 % done after 7.515096187591553 seconds
# 79.88688094909642 % done after 8.015159606933594 seconds
# 84.88067319630294 % done after 8.514224290847778 seconds
# 89.87446544350945 % done after 9.012572050094604 seconds
# 94.86825769071596 % done after 9.511057615280151 seconds
# 99.86204993792248 % done after 10.01432490348816 seconds
# Computing Symmetric PSF for output:
# 4.979997240998759 % done after 0.33846378326416016 seconds
# 9.97378948820527 % done after 0.6793303489685059 seconds
# 14.96758173541178 % done after 1.0209870338439941 seconds
# 19.96137398261829 % done after 1.3638916015625 seconds
# 24.955166229824805 % done after 1.7097325325012207 seconds
# 29.948958477031315 % done after 2.0557894706726074 seconds
# 34.942750724237825 % done after 2.4359946250915527 seconds
# 39.93654297144434 % done after 2.8216371536254883 seconds
# 44.930335218650846 % done after 3.172149419784546 seconds
# 49.92412746585736 % done after 3.5200135707855225 seconds
# 54.917919713063874 % done after 3.862138271331787 seconds
# 59.91171196027038 % done after 4.204226016998291 seconds
# 64.9055042074769 % done after 4.5487425327301025 seconds
# 69.89929645468341 % done after 4.894006729125977 seconds
# 74.89308870188992 % done after 5.237784147262573 seconds
# 79.88688094909642 % done after 5.5810511112213135 seconds
# 84.88067319630294 % done after 5.927421569824219 seconds
# 89.87446544350945 % done after 6.2699244022369385 seconds
# 94.86825769071596 % done after 6.612445592880249 seconds
# 99.86204993792248 % done after 6.954954385757446 seconds
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Use of unsupported NumPy function 'numpy.unravel_index' or unsupported use of the function.
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
# During: typing of get attribute at /home/yjzhu/spice_psf/util.py (40)
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "_masked_medfilt_inner" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "../../../spice_psf/util.py", line 37:
# def masked_median_filter(data,mask,radius,footprint=None,missing=0.0,footprint_ind_offset=0):
#     <source elided>
#
# @numba.jit(fastmath=True, parallel=True)
# ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../spice_psf/util.py", line 37:
# def masked_median_filter(data,mask,radius,footprint=None,missing=0.0,footprint_ind_offset=0):
#     <source elided>
#
# @numba.jit(fastmath=True, parallel=True)
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Use of unsupported NumPy function 'numpy.unravel_index' or unsupported use of the function.
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
# During: typing of get attribute at /home/yjzhu/spice_psf/util.py (40)
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "_masked_medfilt_inner" was compiled in object mode without forceobj=True.
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# Correcting the PSF:
# 7.32448148727417 s; Finished slit index 0 of 192 17 of 40 iterations taken, chi^2= 0.03558608033262422
# 15.47575855255127 s; Finished slit index 1 of 192 18 of 40 iterations taken, chi^2= 0.02689693772536849
# 22.5406231880188 s; Finished slit index 2 of 192 17 of 40 iterations taken, chi^2= 0.032850380106421155
# 30.6380717754364 s; Finished slit index 3 of 192 19 of 40 iterations taken, chi^2= 0.027521800365703234
# 38.23080134391785 s; Finished slit index 4 of 192 19 of 40 iterations taken, chi^2= 0.02641137375953818
# 46.271897077560425 s; Finished slit index 5 of 192 20 of 40 iterations taken, chi^2= 0.029778126675520634
# 54.9363112449646 s; Finished slit index 6 of 192 21 of 40 iterations taken, chi^2= 0.028094321526849386
# 62.15017294883728 s; Finished slit index 7 of 192 18 of 40 iterations taken, chi^2= 0.02928469073733536
# 70.14697766304016 s; Finished slit index 8 of 192 20 of 40 iterations taken, chi^2= 0.028669751328984062
# 75.69833660125732 s; Finished slit index 9 of 192 20 of 40 iterations taken, chi^2= 0.029050624624082807
# 84.48824882507324 s; Finished slit index 10 of 192 30 of 40 iterations taken, chi^2= 0.031247039963586985
# 90.37237167358398 s; Finished slit index 11 of 192 17 of 40 iterations taken, chi^2= 0.02964681414929556
# 97.77161526679993 s; Finished slit index 12 of 192 21 of 40 iterations taken, chi^2= 0.02828448015718288
# 105.47241115570068 s; Finished slit index 13 of 192 21 of 40 iterations taken, chi^2= 0.02404974642808028
# 115.3415174484253 s; Finished slit index 14 of 192 20 of 40 iterations taken, chi^2= 0.020924047872072735
# 125.53331327438354 s; Finished slit index 15 of 192 20 of 40 iterations taken, chi^2= 0.021861637879679527
# 136.39230799674988 s; Finished slit index 16 of 192 23 of 40 iterations taken, chi^2= 0.02214320322653361
# 146.90005326271057 s; Finished slit index 17 of 192 20 of 40 iterations taken, chi^2= 0.019529857701569776
# 159.73046827316284 s; Finished slit index 18 of 192 21 of 40 iterations taken, chi^2= 0.020066122267557045
# 170.29587507247925 s; Finished slit index 19 of 192 20 of 40 iterations taken, chi^2= 0.024467817646187835
# 178.44797682762146 s; Finished slit index 20 of 192 19 of 40 iterations taken, chi^2= 0.023474749753959388
# 184.91371965408325 s; Finished slit index 21 of 192 16 of 40 iterations taken, chi^2= 0.02366941457895344
# 191.93816494941711 s; Finished slit index 22 of 192 18 of 40 iterations taken, chi^2= 0.028947379636812702
# 198.08878421783447 s; Finished slit index 23 of 192 17 of 40 iterations taken, chi^2= 0.024051467048320417
# 205.91146445274353 s; Finished slit index 24 of 192 17 of 40 iterations taken, chi^2= 0.024070580536835917
# 214.58136701583862 s; Finished slit index 25 of 192 18 of 40 iterations taken, chi^2= 0.02481774685368018
# 225.20800709724426 s; Finished slit index 26 of 192 20 of 40 iterations taken, chi^2= 0.020627793158890736
# 238.5832052230835 s; Finished slit index 27 of 192 22 of 40 iterations taken, chi^2= 0.020633997354705405
# 252.0855748653412 s; Finished slit index 28 of 192 23 of 40 iterations taken, chi^2= 0.021847105547240172
# 260.07492327690125 s; Finished slit index 29 of 192 15 of 40 iterations taken, chi^2= 0.02401337780115508
# 272.8212220668793 s; Finished slit index 30 of 192 22 of 40 iterations taken, chi^2= 0.019701488441162582
# 285.94621086120605 s; Finished slit index 31 of 192 22 of 40 iterations taken, chi^2= 0.021913358410831783
# 297.03184700012207 s; Finished slit index 32 of 192 19 of 40 iterations taken, chi^2= 0.022983955038176438
# 307.9329810142517 s; Finished slit index 33 of 192 20 of 40 iterations taken, chi^2= 0.024201615308840033
# 320.42380142211914 s; Finished slit index 34 of 192 21 of 40 iterations taken, chi^2= 0.02243953636098573
# 329.51191902160645 s; Finished slit index 35 of 192 18 of 40 iterations taken, chi^2= 0.022057046302834282
# 338.63333010673523 s; Finished slit index 36 of 192 22 of 40 iterations taken, chi^2= 0.0244014898044508
# 351.64018845558167 s; Finished slit index 37 of 192 21 of 40 iterations taken, chi^2= 0.023389019513083833
# 365.2272267341614 s; Finished slit index 38 of 192 22 of 40 iterations taken, chi^2= 0.02163476977481319
# 378.72605085372925 s; Finished slit index 39 of 192 23 of 40 iterations taken, chi^2= 0.023848252268894757
# 390.6714017391205 s; Finished slit index 40 of 192 19 of 40 iterations taken, chi^2= 0.021860668242274697
# 401.2849235534668 s; Finished slit index 41 of 192 20 of 40 iterations taken, chi^2= 0.02192701600790309
# 416.38746523857117 s; Finished slit index 42 of 192 22 of 40 iterations taken, chi^2= 0.02309648234898356
# 432.221351146698 s; Finished slit index 43 of 192 23 of 40 iterations taken, chi^2= 0.024099375612024694
# 444.83672523498535 s; Finished slit index 44 of 192 21 of 40 iterations taken, chi^2= 0.021935142734360903
# 454.65625953674316 s; Finished slit index 45 of 192 18 of 40 iterations taken, chi^2= 0.025389699464629926
# 463.1670985221863 s; Finished slit index 46 of 192 18 of 40 iterations taken, chi^2= 0.026237168213350058
# 472.32545375823975 s; Finished slit index 47 of 192 21 of 40 iterations taken, chi^2= 0.029123249770089572
# 479.96639370918274 s; Finished slit index 48 of 192 18 of 40 iterations taken, chi^2= 0.029270951604553137
# 487.2585029602051 s; Finished slit index 49 of 192 17 of 40 iterations taken, chi^2= 0.02715661851572659
# 495.22778367996216 s; Finished slit index 50 of 192 19 of 40 iterations taken, chi^2= 0.028683307440329545
# 502.84432101249695 s; Finished slit index 51 of 192 19 of 40 iterations taken, chi^2= 0.028474654068286507
# 508.5598347187042 s; Finished slit index 52 of 192 17 of 40 iterations taken, chi^2= 0.036299137420455006
# 517.184003829956 s; Finished slit index 53 of 192 26 of 40 iterations taken, chi^2= 0.036208672015427025
# 524.4372687339783 s; Finished slit index 54 of 192 20 of 40 iterations taken, chi^2= 0.03962902213845347
# 531.9201622009277 s; Finished slit index 55 of 192 21 of 40 iterations taken, chi^2= 0.03552555297138261
# 537.1546411514282 s; Finished slit index 56 of 192 19 of 40 iterations taken, chi^2= 0.0387274605658784
# 542.137834072113 s; Finished slit index 57 of 192 17 of 40 iterations taken, chi^2= 0.03388687022230429
# 550.6181998252869 s; Finished slit index 58 of 192 22 of 40 iterations taken, chi^2= 0.0350700386028206
# 557.2978093624115 s; Finished slit index 59 of 192 18 of 40 iterations taken, chi^2= 0.03604296099690873
# 566.9500043392181 s; Finished slit index 60 of 192 23 of 40 iterations taken, chi^2= 0.03589811383647673
# 574.0697491168976 s; Finished slit index 61 of 192 19 of 40 iterations taken, chi^2= 0.04131295818919632
# 580.9511253833771 s; Finished slit index 62 of 192 18 of 40 iterations taken, chi^2= 0.034724975593154093
# 589.9003319740295 s; Finished slit index 63 of 192 20 of 40 iterations taken, chi^2= 0.03199230602685511
# 597.9512920379639 s; Finished slit index 64 of 192 18 of 40 iterations taken, chi^2= 0.03174779720967103
# 607.4539642333984 s; Finished slit index 65 of 192 21 of 40 iterations taken, chi^2= 0.03189448026896585
# 617.8724572658539 s; Finished slit index 66 of 192 20 of 40 iterations taken, chi^2= 0.032339793210558486
# 626.9056437015533 s; Finished slit index 67 of 192 24 of 40 iterations taken, chi^2= 0.035785916949430153
# 634.537308216095 s; Finished slit index 68 of 192 19 of 40 iterations taken, chi^2= 0.03273317107210879
# 640.9518027305603 s; Finished slit index 69 of 192 16 of 40 iterations taken, chi^2= 0.03442488876692274
# 649.082896232605 s; Finished slit index 70 of 192 18 of 40 iterations taken, chi^2= 0.02844680463860309
# 655.8922374248505 s; Finished slit index 71 of 192 17 of 40 iterations taken, chi^2= 0.03636868169770323
# 661.3699579238892 s; Finished slit index 72 of 192 20 of 40 iterations taken, chi^2= 0.04667737343905215
# 668.8356969356537 s; Finished slit index 73 of 192 29 of 40 iterations taken, chi^2= 0.05022053926776826
# 675.4895617961884 s; Finished slit index 74 of 192 24 of 40 iterations taken, chi^2= 0.048127336358059984
# 681.8816528320312 s; Finished slit index 75 of 192 22 of 40 iterations taken, chi^2= 0.04558099721520911
# 686.9062685966492 s; Finished slit index 76 of 192 20 of 40 iterations taken, chi^2= 0.04520223706185377
# 694.6281595230103 s; Finished slit index 77 of 192 20 of 40 iterations taken, chi^2= 0.03858461626559223
# 700.8312330245972 s; Finished slit index 78 of 192 20 of 40 iterations taken, chi^2= 0.040603211233459086
# 704.6961536407471 s; Finished slit index 79 of 192 16 of 40 iterations taken, chi^2= 0.04358711641851766
# 711.7441117763519 s; Finished slit index 80 of 192 29 of 40 iterations taken, chi^2= 0.05155480889321096
# 719.7108435630798 s; Finished slit index 81 of 192 28 of 40 iterations taken, chi^2= 0.06260262814751354
# 727.9961800575256 s; Finished slit index 82 of 192 29 of 40 iterations taken, chi^2= 0.057165181886131324
# 738.4021644592285 s; Finished slit index 83 of 192 33 of 40 iterations taken, chi^2= 0.05433429169659496
# 745.7862219810486 s; Finished slit index 84 of 192 23 of 40 iterations taken, chi^2= 0.05800709785242337
# 751.9737062454224 s; Finished slit index 85 of 192 22 of 40 iterations taken, chi^2= 0.04338828804509537
# 759.7538077831268 s; Finished slit index 86 of 192 28 of 40 iterations taken, chi^2= 0.0532747236241787
# 768.3455667495728 s; Finished slit index 87 of 192 28 of 40 iterations taken, chi^2= 0.05093303927154257
# 776.8301701545715 s; Finished slit index 88 of 192 31 of 40 iterations taken, chi^2= 0.06525952985169471
# 782.9870598316193 s; Finished slit index 89 of 192 24 of 40 iterations taken, chi^2= 0.06635495505654658
# 790.1791000366211 s; Finished slit index 90 of 192 25 of 40 iterations taken, chi^2= 0.05727863256151957
# 798.1458094120026 s; Finished slit index 91 of 192 27 of 40 iterations taken, chi^2= 0.04764765212933054
# 805.8463113307953 s; Finished slit index 92 of 192 22 of 40 iterations taken, chi^2= 0.03707852213045585
# 814.2894225120544 s; Finished slit index 93 of 192 22 of 40 iterations taken, chi^2= 0.035382551611203454
# 823.2155830860138 s; Finished slit index 94 of 192 21 of 40 iterations taken, chi^2= 0.029650146229660314
# 831.7266600131989 s; Finished slit index 95 of 192 18 of 40 iterations taken, chi^2= 0.03172446538262419
# 841.8463799953461 s; Finished slit index 96 of 192 22 of 40 iterations taken, chi^2= 0.029224685331088827
# 852.1173264980316 s; Finished slit index 97 of 192 20 of 40 iterations taken, chi^2= 0.025873579373528317
# 862.6324832439423 s; Finished slit index 98 of 192 21 of 40 iterations taken, chi^2= 0.02360857195056199
# 872.9163930416107 s; Finished slit index 99 of 192 19 of 40 iterations taken, chi^2= 0.024236478634457933
# 882.9467575550079 s; Finished slit index 100 of 192 18 of 40 iterations taken, chi^2= 0.021075967728220745
# 893.2808473110199 s; Finished slit index 101 of 192 20 of 40 iterations taken, chi^2= 0.02286846135369656
# 901.6893389225006 s; Finished slit index 102 of 192 19 of 40 iterations taken, chi^2= 0.023932920524239534
# 909.9619545936584 s; Finished slit index 103 of 192 20 of 40 iterations taken, chi^2= 0.02812413535730079
# 919.1529326438904 s; Finished slit index 104 of 192 22 of 40 iterations taken, chi^2= 0.02947486534408879
# 925.3973824977875 s; Finished slit index 105 of 192 21 of 40 iterations taken, chi^2= 0.030376300617339504
# 932.6958155632019 s; Finished slit index 106 of 192 19 of 40 iterations taken, chi^2= 0.03116517123930883
# 940.6751420497894 s; Finished slit index 107 of 192 20 of 40 iterations taken, chi^2= 0.03294603293543873
# 949.3862919807434 s; Finished slit index 108 of 192 23 of 40 iterations taken, chi^2= 0.043750759510948735
# 958.0391149520874 s; Finished slit index 109 of 192 23 of 40 iterations taken, chi^2= 0.04011500019463469
# 966.6091480255127 s; Finished slit index 110 of 192 19 of 40 iterations taken, chi^2= 0.03973285568989624
# 973.9686138629913 s; Finished slit index 111 of 192 23 of 40 iterations taken, chi^2= 0.04272161193740121
# 979.844598531723 s; Finished slit index 112 of 192 20 of 40 iterations taken, chi^2= 0.04630905829999839
# 987.2621665000916 s; Finished slit index 113 of 192 23 of 40 iterations taken, chi^2= 0.05448262951908901
# 995.1413350105286 s; Finished slit index 114 of 192 26 of 40 iterations taken, chi^2= 0.06811610374527119
# 1001.6110391616821 s; Finished slit index 115 of 192 27 of 40 iterations taken, chi^2= 0.10842827889937731
# 1008.3744990825653 s; Finished slit index 116 of 192 28 of 40 iterations taken, chi^2= 0.12006935447077285
# 1013.6670506000519 s; Finished slit index 117 of 192 29 of 40 iterations taken, chi^2= 0.15085681975039203
# 1019.6798672676086 s; Finished slit index 118 of 192 30 of 40 iterations taken, chi^2= 0.15070726062012943
# 1026.1236050128937 s; Finished slit index 119 of 192 33 of 40 iterations taken, chi^2= 0.1433708133816361
# 1033.6595575809479 s; Finished slit index 120 of 192 34 of 40 iterations taken, chi^2= 0.1353237744758872
# 1040.4341702461243 s; Finished slit index 121 of 192 28 of 40 iterations taken, chi^2= 0.11063568036659233
# 1048.5003345012665 s; Finished slit index 122 of 192 28 of 40 iterations taken, chi^2= 0.11552815360643107
# 1056.0235888957977 s; Finished slit index 123 of 192 25 of 40 iterations taken, chi^2= 0.1020365408410197
# 1066.006358385086 s; Finished slit index 124 of 192 30 of 40 iterations taken, chi^2= 0.06292757778228177
# 1072.1429224014282 s; Finished slit index 125 of 192 22 of 40 iterations taken, chi^2= 0.060932260752423716
# 1078.6432933807373 s; Finished slit index 126 of 192 28 of 40 iterations taken, chi^2= 0.09619260826291033
# 1085.8409481048584 s; Finished slit index 127 of 192 30 of 40 iterations taken, chi^2= 0.0977977852130987
# 1093.845998764038 s; Finished slit index 128 of 192 30 of 40 iterations taken, chi^2= 0.08554960894893836
# 1101.6290690898895 s; Finished slit index 129 of 192 27 of 40 iterations taken, chi^2= 0.0712098130933212
# 1109.2047863006592 s; Finished slit index 130 of 192 25 of 40 iterations taken, chi^2= 0.05952871840504684
# 1117.0035285949707 s; Finished slit index 131 of 192 26 of 40 iterations taken, chi^2= 0.04825281637073532
# 1121.858915090561 s; Finished slit index 132 of 192 20 of 40 iterations taken, chi^2= 0.05329554203850413
# 1127.3490509986877 s; Finished slit index 133 of 192 18 of 40 iterations taken, chi^2= 0.044096716197195907
# 1132.807933330536 s; Finished slit index 134 of 192 18 of 40 iterations taken, chi^2= 0.03646665974697334
# 1140.2835900783539 s; Finished slit index 135 of 192 26 of 40 iterations taken, chi^2= 0.039176474567244886
# 1148.1479287147522 s; Finished slit index 136 of 192 26 of 40 iterations taken, chi^2= 0.03852234184026569
# 1155.598426580429 s; Finished slit index 137 of 192 26 of 40 iterations taken, chi^2= 0.041168700677903805
# 1163.4150097370148 s; Finished slit index 138 of 192 26 of 40 iterations taken, chi^2= 0.03870543329377364
# 1170.4872362613678 s; Finished slit index 139 of 192 24 of 40 iterations taken, chi^2= 0.038200942517481885
# 1178.4248821735382 s; Finished slit index 140 of 192 27 of 40 iterations taken, chi^2= 0.05186336844982424
# 1185.5312011241913 s; Finished slit index 141 of 192 23 of 40 iterations taken, chi^2= 0.0417204857679405
# 1193.9841628074646 s; Finished slit index 142 of 192 22 of 40 iterations taken, chi^2= 0.03981641224604041
# 1199.7585771083832 s; Finished slit index 143 of 192 18 of 40 iterations taken, chi^2= 0.038630293005125646
# 1205.7775211334229 s; Finished slit index 144 of 192 18 of 40 iterations taken, chi^2= 0.04068634975882685
# 1212.6655554771423 s; Finished slit index 145 of 192 19 of 40 iterations taken, chi^2= 0.03949801070934269
# 1220.3126032352448 s; Finished slit index 146 of 192 19 of 40 iterations taken, chi^2= 0.038780078309747966
# 1228.3182439804077 s; Finished slit index 147 of 192 19 of 40 iterations taken, chi^2= 0.03948807737947113
# 1235.6881086826324 s; Finished slit index 148 of 192 20 of 40 iterations taken, chi^2= 0.04101538364108396
# 1241.491893529892 s; Finished slit index 149 of 192 18 of 40 iterations taken, chi^2= 0.044644458672402014
# 1246.3888907432556 s; Finished slit index 150 of 192 20 of 40 iterations taken, chi^2= 0.04629370050148719
# 1250.5415523052216 s; Finished slit index 151 of 192 27 of 40 iterations taken, chi^2= 0.08079761477522993
# 1255.4298725128174 s; Finished slit index 152 of 192 25 of 40 iterations taken, chi^2= 0.06281526644799316
# 1259.1193330287933 s; Finished slit index 153 of 192 18 of 40 iterations taken, chi^2= 0.04113175976292685
# 1266.7809903621674 s; Finished slit index 154 of 192 20 of 40 iterations taken, chi^2= 0.03449326422725154
# 1271.3778779506683 s; Finished slit index 155 of 192 18 of 40 iterations taken, chi^2= 0.04116617607090624
# 1278.4613950252533 s; Finished slit index 156 of 192 22 of 40 iterations taken, chi^2= 0.03849012937114773
# 1285.9465773105621 s; Finished slit index 157 of 192 21 of 40 iterations taken, chi^2= 0.03429782941257866
# 1290.1463577747345 s; Finished slit index 158 of 192 19 of 40 iterations taken, chi^2= 0.043668748176696276
# 1295.908013343811 s; Finished slit index 159 of 192 19 of 40 iterations taken, chi^2= 0.039148997366413626
# 1303.6722807884216 s; Finished slit index 160 of 192 22 of 40 iterations taken, chi^2= 0.034405644991756426
# 1310.4988808631897 s; Finished slit index 161 of 192 17 of 40 iterations taken, chi^2= 0.03195015610561366
# 1319.4749796390533 s; Finished slit index 162 of 192 20 of 40 iterations taken, chi^2= 0.029728782463754058
# 1326.252239704132 s; Finished slit index 163 of 192 18 of 40 iterations taken, chi^2= 0.031965780139554145
# 1335.5960404872894 s; Finished slit index 164 of 192 22 of 40 iterations taken, chi^2= 0.030138802132688464
# 1342.1900079250336 s; Finished slit index 165 of 192 17 of 40 iterations taken, chi^2= 0.03123325512312098
# 1348.823486328125 s; Finished slit index 166 of 192 17 of 40 iterations taken, chi^2= 0.030557520097503548
# 1356.914669752121 s; Finished slit index 167 of 192 22 of 40 iterations taken, chi^2= 0.031738594589890555
# 1365.173178911209 s; Finished slit index 168 of 192 20 of 40 iterations taken, chi^2= 0.03191578185186852
# 1373.4688110351562 s; Finished slit index 169 of 192 19 of 40 iterations taken, chi^2= 0.025991215855150074
# 1381.9516682624817 s; Finished slit index 170 of 192 19 of 40 iterations taken, chi^2= 0.028689031864782326
# 1391.6928081512451 s; Finished slit index 171 of 192 20 of 40 iterations taken, chi^2= 0.02607015761260459
# 1402.612907409668 s; Finished slit index 172 of 192 21 of 40 iterations taken, chi^2= 0.022672970194251046
# 1411.9602193832397 s; Finished slit index 173 of 192 20 of 40 iterations taken, chi^2= 0.021901379281312562
# 1421.3257007598877 s; Finished slit index 174 of 192 18 of 40 iterations taken, chi^2= 0.02545389122487694
# 1429.8876602649689 s; Finished slit index 175 of 192 18 of 40 iterations taken, chi^2= 0.02276947188826982
# 1438.216914653778 s; Finished slit index 176 of 192 19 of 40 iterations taken, chi^2= 0.022167281806471286
# 1448.9220249652863 s; Finished slit index 177 of 192 20 of 40 iterations taken, chi^2= 0.023412599293145292
# 1458.8202259540558 s; Finished slit index 178 of 192 17 of 40 iterations taken, chi^2= 0.0229212177677721
# 1470.0931408405304 s; Finished slit index 179 of 192 20 of 40 iterations taken, chi^2= 0.018742528708320074
# 1484.5601210594177 s; Finished slit index 180 of 192 27 of 40 iterations taken, chi^2= 0.019080527780433152
# 1496.1942462921143 s; Finished slit index 181 of 192 23 of 40 iterations taken, chi^2= 0.02051916868083021
# 1509.33323097229 s; Finished slit index 182 of 192 22 of 40 iterations taken, chi^2= 0.01886124973961696
# 1521.7682688236237 s; Finished slit index 183 of 192 20 of 40 iterations taken, chi^2= 0.022022402974629984
# 1531.163945198059 s; Finished slit index 184 of 192 19 of 40 iterations taken, chi^2= 0.018773529255953287
# 1545.1727290153503 s; Finished slit index 185 of 192 23 of 40 iterations taken, chi^2= 0.01916148865887638
# 1562.7534627914429 s; Finished slit index 186 of 192 27 of 40 iterations taken, chi^2= 0.022219083932300043
# 1573.5746314525604 s; Finished slit index 187 of 192 20 of 40 iterations taken, chi^2= 0.024661050138162166
# 1586.099361896515 s; Finished slit index 188 of 192 33 of 40 iterations taken, chi^2= 0.02334540998774799
# 1593.5043516159058 s; Finished slit index 189 of 192 20 of 40 iterations taken, chi^2= 0.02594216844297773
# 1602.5151035785675 s; Finished slit index 190 of 192 28 of 40 iterations taken, chi^2= 0.032900307531001774
# 1612.2842116355896 s; Finished slit index 191 of 192 38 of 40 iterations taken, chi^2= 0.035884424700375714

# %%
spice_sdev_guess = 0.1
corr_sdev_guess = 0.05


spice_mask, spice_err = get_mask_errs(spice_dat1.astype(np.float64), spice_err_fac)
spice_corr_mask, spice_corr_err = get_mask_errs(spice_corr_dat, spice_err_fac)

[det_origin0, det_dims0, det_scale0] = metadict["det_origin0"], metadict["det_dims0"], metadict["det_scale0"]
spice_la = spice_NeVIII_770_window.spectral_axis.to_value("Angstrom")
spice_wlcen0 = spice_la[np.nanargmax(np.nanmean(spice_dat1[:,:,:], axis=(0,1)))]
# Out:
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Use of unsupported NumPy function 'numpy.unravel_index' or unsupported use of the function.
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
# During: typing of get attribute at /home/yjzhu/spice_psf/util.py (40)
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "_masked_medfilt_inner" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "../../../spice_psf/util.py", line 37:
# def masked_median_filter(data,mask,radius,footprint=None,missing=0.0,footprint_ind_offset=0):
#     <source elided>
#
# @numba.jit(fastmath=True, parallel=True)
# ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../spice_psf/util.py", line 37:
# def masked_median_filter(data,mask,radius,footprint=None,missing=0.0,footprint_ind_offset=0):
#     <source elided>
#
# @numba.jit(fastmath=True, parallel=True)
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Use of unsupported NumPy function 'numpy.unravel_index' or unsupported use of the function.
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
# During: typing of get attribute at /home/yjzhu/spice_psf/util.py (40)
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "_masked_medfilt_inner" was compiled in object mode without forceobj=True.
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Use of unsupported NumPy function 'numpy.unravel_index' or unsupported use of the function.
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
# During: typing of get attribute at /home/yjzhu/spice_psf/util.py (40)
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "_masked_medfilt_inner" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "../../../spice_psf/util.py", line 37:
# def masked_median_filter(data,mask,radius,footprint=None,missing=0.0,footprint_ind_offset=0):
#     <source elided>
#
# @numba.jit(fastmath=True, parallel=True)
# ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../spice_psf/util.py", line 37:
# def masked_median_filter(data,mask,radius,footprint=None,missing=0.0,footprint_ind_offset=0):
#     <source elided>
#
# @numba.jit(fastmath=True, parallel=True)
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# /home/yjzhu/spice_psf/util.py:37: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_masked_medfilt_inner" failed type inference due to: Use of unsupported NumPy function 'numpy.unravel_index' or unsupported use of the function.
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
# During: typing of get attribute at /home/yjzhu/spice_psf/util.py (40)
#
# File "../../../spice_psf/util.py", line 40:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     <source elided>
#     for ind in flatinds:
#         ijkpad = np.unravel_index(ind,data.shape)+footprint_inds-footprint_ind_offset
#         ^
#
#   @numba.jit(fastmath=True, parallel=True)
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "_masked_medfilt_inner" was compiled in object mode without forceobj=True.
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/yjzhu/miniconda3/envs/sunpy/lib/python3.11/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "../../../spice_psf/util.py", line 39:
# def _masked_medfilt_inner(flatinds,data,footprint_inds,footprint_ind_offset,tparg,dat_pad_shape,data_fppad,mask_fppad,data_filt):
#     for ind in flatinds:
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# /tmp/ipykernel_16712/844281563.py:10: RuntimeWarning: Mean of empty slice
#   spice_wlcen0 = spice_la[np.nanargmax(np.nanmean(spice_dat1[:,:,:], axis=(0,1)))]

# %%
spice_fits = fsl(spice_dat1, spice_err, spice_la, spice_mask, spice_wlcen0, spice_sdev_guess)

spice_corr_fits = fsl(spice_corr_dat, spice_corr_err, spice_la, spice_corr_mask, spice_wlcen0, corr_sdev_guess)
# Out:
# 0 of 192 0.0
# 10 of 192 0.0
# 20 of 192 0.0
# 30 of 192 0.0
# 40 of 192 0.0
# 50 of 192 0.0
# 60 of 192 0.0
# 70 of 192 0.0
# 80 of 192 0.0
# 90 of 192 0.0
# 100 of 192 0.0
# 110 of 192 0.0
# 120 of 192 0.0
# 130 of 192 0.0
# 140 of 192 0.0
# 150 of 192 0.0
# 160 of 192 0.0
# 170 of 192 0.0
# 180 of 192 0.0
# 190 of 192 0.0
# 191 of 192 0.0
# 0 of 192 0.0
# 10 of 192 0.0
# 20 of 192 0.0
# 30 of 192 0.0
# 40 of 192 0.0
# 50 of 192 0.0
# 60 of 192 0.0
# 70 of 192 0.0
# 80 of 192 0.0
# 90 of 192 0.0
# 100 of 192 0.0
# 110 of 192 0.0
# 120 of 192 0.0
# 130 of 192 0.0
# 140 of 192 0.0
# 150 of 192 0.0
# 160 of 192 0.0
# 170 of 192 0.0
# 180 of 192 0.0
# 190 of 192 0.0
# 191 of 192 0.0

# %%
spice_origin_vel = (spice_fits["centers"].T/spice_wlcen0 - 1)*const.c.to_value("km/s")
spice_origin_vel = spice_origin_vel - np.nanmedian(spice_origin_vel[:,:])

spice_corr_vel = (spice_corr_fits["centers"].T/spice_wlcen0 - 1)*const.c.to_value("km/s")
spice_corr_vel = spice_corr_vel - np.nanmedian(spice_corr_vel[:,:])

# %%
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(10,10),layout="constrained")

int_norm = ImageNormalize(stretch=AsinhStretch(0.1))

ax1.imshow(spice_fits["amplitudes"].T,origin="lower",norm=int_norm,aspect=1,
           cmap="sdoaia171")
plt.colorbar(ax1.images[0],ax=ax1)
ax1.set_title("Original")

ax2.imshow(spice_corr_fits["amplitudes"].T,origin="lower",norm=int_norm,aspect=1,
              cmap="sdoaia171")
plt.colorbar(ax2.images[0],ax=ax2)
ax2.set_title("Corrected")
# Out:
# Text(0.5, 1.0, 'Corrected')

# %%
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(10,10),layout="constrained")

ax1.imshow(spice_origin_vel,origin="lower",vmin=-40,vmax=40,aspect=1,
           cmap="RdBu_r")
plt.colorbar(ax1.images[0],ax=ax1)
ax1.set_title("Original")

ax2.imshow(spice_corr_vel,origin="lower",vmin=-40,vmax=40,aspect=1,
                cmap="RdBu_r")
plt.colorbar(ax2.images[0],ax=ax2)
ax2.set_title("Corrected")

for ax_ in (ax1,ax2):
    ax_.scatter(62,90,color="yellow",marker="x")

# %%
NeVIII_770_window_wvl = spice_NeVIII_770_window.spectral_axis.to_value("Angstrom")
NeVIII_deconv_rebin_fitmodel = SpectrumFit2D(spice_corr_dat[:,:,16:30].transpose([1,0,2]).astype(np.float32), NeVIII_770_window_wvl[16:30],
                                line_number=1,line_wvl_init=[770],int_max_init=0.2,fwhm_init=1,
                                same_width=False)
NeVIII_deconv_rebin_fitmodel.run_lse_mp(prev_init=False)
# Out:
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:221: UserWarning: No input errors, absolute_sigma=False will be used in the Chi2 fitting.
#   warn("No input errors, absolute_sigma=False will be used in the Chi2 fitting.")
# /home/yjzhu/SOLAR/MyPy/juanfit.py:277: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(self.multi_gaussian_diff_width, self.wvl_tofit, self.data_tofit,

# %%
NeVIII_deconv_rebin_fitmodel.plot_fit2d(param="vel",vmin=-30,vmax=30,vel_corr="column",ref_wvl=770.03,   
                                    aspect=1,cmap="RdBu")
# Out:
# Doppler velocity corrected by the median of each raster.

# %%
spice_corr_dat.shape
# Out:
# (192, 145, 50)

# %%
plt.plot(NeVIII_770_window_wvl, spice_corr_dat[145,50,:])
plt.plot(NeVIII_770_window_wvl, spice_dat1[145,50,:])

# %%
plt.plot(NeVIII_770_window_wvl, spice_corr_dat[60,62,:])
plt.plot(NeVIII_770_window_wvl, spice_dat1[60,62,:])
plt.axvline(NeVIII_770_window_wvl[15])
plt.axvline(NeVIII_770_window_wvl[30])

# %%
plt.plot(NeVIII_770_window_wvl, spice_corr_dat[10,20,:])
plt.plot(NeVIII_770_window_wvl, spice_dat1[10,20,:])

# %%
plt.imshow(spice_corr_dat[175,:,:],origin="lower",aspect=1/4,
           norm=ImageNormalize(stretch=AsinhStretch(0.01)))

# %%
plt.imshow(spice_dat1[151,:,:],origin="lower",aspect=1/4,
           norm=ImageNormalize(stretch=AsinhStretch(0.01)))
plt.axvline(15)
plt.axvline(34)

# %%
spice_corr_dat.shape
# Out:
# (192, 145, 50)
