# %%
from saffron.manager.manager import Manager
from saffron.utils import get_input_template
import sospice
import sunpy.map
# Out:
# XUVTOP is already set to: home/yjzhu/SOLAR/CHIANTI/dbase
# /home/yjzhu/miniconda3/envs/sospice/lib/python3.9/site-packages/sospice/util/fov.py:13: UserWarning: could not determine sunpy_soar package version; this indicates a broken installation
#   import sunpy_soar  # noqa: F401
# fit_models initiated
#  ChiantiPy version 0.15.1
#  using cli
#  using CLI for selections
# Traceback (most recent call last):
#   File "/home/yjzhu/miniconda3/envs/sospice/lib/python3.9/site-packages/fiplcr/specline/specline.py", line 39, in <module>
#     import chianti.core as ch
# ModuleNotFoundError: No module named 'chianti'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/yjzhu/miniconda3/envs/sospice/lib/python3.9/site-packages/ChiantiPy/tools/data.py", line 47, in <module>
#     Ip = chio.ipRead()
#   File "/home/yjzhu/miniconda3/envs/sospice/lib/python3.9/site-packages/ChiantiPy/tools/io.py", line 1430, in ipRead
#     ipfile = open(ipname)
# FileNotFoundError: [Errno 2] No such file or directory: 'home/yjzhu/SOLAR/CHIANTI/dbase/ip/chianti.ip'
# /home/yjzhu/miniconda3/envs/sospice/lib/python3.9/site-packages/ChiantiPy/tools/data.py:81: UserWarning: Cannot find the CHIANTI atomic database at home/yjzhu/SOLAR/CHIANTI/dbase. You will not be able to access any data from the CHIANTI database.
#   warnings.warn(
# using ChiantiPy

# %%
#get_input_template(where='./saffron_json/input_1020.json')

# %%
session = Manager("./saffron_json/input_20230330.json")

# %%
session.build_files_list()

# %%
session.build_rasters()
# Out:
# loading from  /home/yjzhu/miniconda3/envs/sospice/lib/python3.9/site-packages/saffron/line_catalog/SPICE_SpecLines.json
# _______________________________________
# O III 703 / Mg IX 706 (Merged):
# 	o_iii_1  at 0702.7 in index 28
# 	o_iii_2  at 0703.9 in index 40
# 	mg_ix_1  at 0706.0 in index 62
# _______________________________________
# _______________________________________
# O II 718 - Peak (spectral bin 2):
# 	o_ii     at 0718.5 in index 14
# _______________________________________
# _______________________________________
# O V 760 (Merged):
# 	o_v_1    at 0759.0 in index 34
# 	o_v_2    at 0760.4 in index 49
# 	o_v_3    at 0762.0 in index 65
# _______________________________________
#  --Warning--
# The current line is far from the target line
# 	target =763.0533195o_v_2
# 	current:759.9804612515399
# 	\lines[name     o_v_1
# wvl      759.0
# index       34
# Name: 10, dtype: object, name      o_v_2
# wvl      760.43
# index        49
# Name: 11, dtype: object, name      o_v_3
# wvl      761.99
# index        65
# Name: 12, dtype: object]
# trying to confine the boundaries
# between 0759.0 Angstroms and 0761.0 Angstroms
# _______________________________________
# N IV 765 - Peak:
# 	n_iv     at 0765.1 in index 15
# _______________________________________
# _______________________________________
# Ne VIII 770 - Peak:
# 	ne_viii_1 at 0770.4 in index 15
# _______________________________________
# _______________________________________
# S V 786 / O IV 787 (Merged):
# 	s_v      at 0786.5 in index 18
# 	o_iv_1   at 0787.7 in index 24
# 	o_iv_2   at 0790.2 in index 37
# _______________________________________
#  --Warning--
# The current line is far from the target line
# 	target =789.821736o_iv_1
# 	current:787.2704612515399
# 	\lines[name        s_v
# wvl      786.47
# index        18
# Name: 17, dtype: object, name     o_iv_1
# wvl      787.72
# index        24
# Name: 18, dtype: object, name     o_iv_2
# wvl      790.19
# index        37
# Name: 19, dtype: object]
# trying to confine the boundaries
# between 0786.3 Angstroms and 0788.3 Angstroms
# _______________________________________
# C III 977 - Peak:
# 	c_iii    at 0977.0 in index 10
# _______________________________________
# _______________________________________
# Ly Beta 1025 - Peak:
# 	h_i_be   at 1025.7 in index 11
# _______________________________________
# _______________________________________
# O VI 1032 - Peak:
# 	o_vi_1   at 1031.9 in index 10
# _______________________________________
# /home/yjzhu/miniconda3/envs/sospice/lib/python3.9/site-packages/saffron/utils/utils.py:936: RuntimeWarning: Mean of empty slice
#   image = np.nanmean(data, axis=(0, 1))
# /home/yjzhu/miniconda3/envs/sospice/lib/python3.9/site-packages/saffron/utils/utils.py:940: RuntimeWarning: Mean of empty slice
#   spect = np.nanmean(data, axis=(0, 2, 3))

# %%
session.run_preparations()
# Out:
# Getting observation parameters from O III 703 / Mg IX 706 (Merged)
#
# Slit: 4.0 arcsec
# Bin: (1, 1)
# Exposure time: 30.0 s
# Window width: 80.0 pix
# Average wavelength: 70.3811742 nm
# RADCAL: 413.800869984 m2 ct nm sr / W
#
# Getting observation parameters from O II 718 - Peak (spectral bin 2)
#
# Slit: 4.0 arcsec
# Bin: (2, 1)
# Exposure time: 30.0 s
# Window width: 25.0 pix
# Average wavelength: 71.8049224 nm
# RADCAL: 686.593256458 m2 ct nm sr / W
#
# Getting observation parameters from O V 760 (Merged)
#
# Slit: 4.0 arcsec
# Bin: (1, 1)
# Exposure time: 30.0 s
# Window width: 80.0 pix
# Average wavelength: 75.9493949 nm
# RADCAL: 254.170492359 m2 ct nm sr / W
#
# Getting observation parameters from N IV 765 - Peak
#
# Slit: 4.0 arcsec
# Bin: (2, 1)
# Exposure time: 30.0 s
# Window width: 25.0 pix
# Average wavelength: 76.4564833 nm
# RADCAL: 498.281106707 m2 ct nm sr / W
#
# Getting observation parameters from Ne VIII 770 - Peak
#
# Slit: 4.0 arcsec
# Bin: (2, 1)
# Exposure time: 30.0 s
# Window width: 25.0 pix
# Average wavelength: 76.9928268 nm
# RADCAL: 487.435125055 m2 ct nm sr / W
#
# Getting observation parameters from S V 786 / O IV 787 (Merged)
#
# Slit: 4.0 arcsec
# Bin: (2, 1)
# Exposure time: 30.0 s
# Window width: 40.0 pix
# Average wavelength: 78.6798709 nm
# RADCAL: 452.006183053 m2 ct nm sr / W
#
# Getting observation parameters from C III 977 - Peak
#
# Slit: 4.0 arcsec
# Bin: (2, 1)
# Exposure time: 30.0 s
# Window width: 18.0 pix
# Average wavelength: 97.66959299999998 nm
# RADCAL: 146.155960952 m2 ct nm sr / W
#
# Getting observation parameters from Ly Beta 1025 - Peak
#
# Slit: 4.0 arcsec
# Bin: (2, 1)
# Exposure time: 30.0 s
# Window width: 17.0 pix
# Average wavelength: 102.51958499999999 nm
# RADCAL: 149.478912986 m2 ct nm sr / W
#
# Getting observation parameters from O VI 1032 - Peak
#
# Slit: 4.0 arcsec
# Bin: (2, 1)
# Exposure time: 30.0 s
# Window width: 17.0 pix
# Average wavelength: 103.154703 nm
# RADCAL: 144.300932311 m2 ct nm sr / W

# %%
session.fit_manager()
# Out:
# launching following progress
# from file  /home/yjzhu/SOLAR/SPICE_202210/ipynb_saffron/tmp/Progress_Shmm_config_20240806T110840886385.p
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 session.fit_manager()
#
# File ~/miniconda3/envs/sospice/lib/python3.9/site-packages/saffron/manager/manager.py:221, in Manager.fit_manager(self)
#     218 progress_follower = ProgressFollower()
#     220 for i in range(len(self.rasters)):
# --> 221     self.rasters[i].fit_raster(progress_follower=progress_follower)
#
# File ~/miniconda3/envs/sospice/lib/python3.9/site-packages/saffron/fit_functions/fit_raster.py:293, in RasterFit.fit_raster(self, progress_follower)
#     291     progress_follower = ProgressFollower()
#     292 for ind in self.solo_windows_toFit:
# --> 293     self.windows[ind].fit_window(progress_follower=progress_follower)
#     294     self.windows[ind].write_data()
#     295 for window in self.fused_windows:
#
# File ~/miniconda3/envs/sospice/lib/python3.9/site-packages/saffron/fit_functions/fit_raster.py:1487, in WindowFit.fit_window(self, progress_follower)
#    1484     # print("remaining_pixels= ",nan_size,'/',data.size)
#    1485 while True:
#    1486     # print("live processes: ",np.sum([1 for p in Processes if p.is_alive()]))
# -> 1487     if np.sum([1 for p in Processes if p.is_alive()]) >= self.Jobs:
#    1488         if self.verbose >= 1:
#    1489             data = self.data_con[
#    1490                 0,
#    1491                 self.window_size[0, 0] : self.window_size[0, 1],
#    1492                 self.window_size[1, 0] : self.window_size[1, 1],
#    1493             ].copy()
#
# File ~/miniconda3/envs/sospice/lib/python3.9/site-packages/saffron/fit_functions/fit_raster.py:1487, in <listcomp>(.0)
#    1484     # print("remaining_pixels= ",nan_size,'/',data.size)
#    1485 while True:
#    1486     # print("live processes: ",np.sum([1 for p in Processes if p.is_alive()]))
# -> 1487     if np.sum([1 for p in Processes if p.is_alive()]) >= self.Jobs:
#    1488         if self.verbose >= 1:
#    1489             data = self.data_con[
#    1490                 0,
#    1491                 self.window_size[0, 0] : self.window_size[0, 1],
#    1492                 self.window_size[1, 0] : self.window_size[1, 1],
#    1493             ].copy()
#
# File ~/miniconda3/envs/sospice/lib/python3.9/multiprocessing/process.py:165, in BaseProcess.is_alive(self)
#     162 if self._popen is None:
#     163     return False
# --> 165 returncode = self._popen.poll()
#     166 if returncode is None:
#     167     return True
#
# File ~/miniconda3/envs/sospice/lib/python3.9/multiprocessing/popen_fork.py:27, in Popen.poll(self, flag)
#      25 if self.returncode is None:
#      26     try:
# ---> 27         pid, sts = os.waitpid(self.pid, flag)
#      28     except OSError:
#      29         # Child process not yet created. See #1731717
#      30         # e.errno == errno.ECHILD == 10
#      31         return None
#
# KeyboardInterrupt:
